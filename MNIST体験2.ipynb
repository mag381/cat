# %% [markdown]
# <a href="https://colab.research.google.com/github/mag381/cat/blob/main/MNIST%E4%BD%93%E9%A8%932.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import utils as np_utils 
from keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
# 入力と出力を指定
im_rows = 28 # 画像の縦ピクセルサイズ
im_cols = 28 # 画像の横ピクセルサイズ
im_color = 1 # 画像の色空間/グレイスケール
in_shape = (im_rows, im_cols, im_color)
out_size = 10

# %%
# MNISTのデータを読み込み
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(-1, im_rows, im_cols, im_color)
X_train = X_train.astype('float32') / 255
X_test = X_test.reshape(-1, im_rows, im_cols, im_color)
X_test = X_test.astype('float32') / 255
# ラベルデータをone-hotベクトルへ変換
y_train = np_utils.to_categorical(y_train.astype('int32'),10)
y_test = np_utils.to_categorical(y_test.astype('int32'),10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# モデルの構造を設定する
model = Sequential()
model.add(Conv2D(32, 
          kernel_size=(3, 3),
          activation='relu',
          input_shape=in_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(out_size, activation='softmax'))

# %%
# モデルを実行可能な形にする
model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(),
    metrics=['accuracy'])

# %%
# モデルの学習をして、その履歴を hist に残す
hist = model.fit(X_train, y_train,
          batch_size=128, 
          epochs=12,
          verbose=1,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/12
# 469/469 [==============================] - 18s 18ms/step - loss: 0.2119 - accuracy: 0.9348 - val_loss: 0.0555 - val_accuracy: 0.9825
# Epoch 2/12
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0808 - accuracy: 0.9763 - val_loss: 0.0378 - val_accuracy: 0.9864
# Epoch 3/12
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0614 - accuracy: 0.9817 - val_loss: 0.0327 - val_accuracy: 0.9884
# Epoch 4/12
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0522 - accuracy: 0.9848 - val_loss: 0.0332 - val_accuracy: 0.9890
# Epoch 5/12
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0489 - accuracy: 0.9855 - val_loss: 0.0323 - val_accuracy: 0.9894
# Epoch 6/12
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0465 - accuracy: 0.9865 - val_loss: 0.0383 - val_accuracy: 0.9875
# Epoch 7/12
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0447 - accuracy: 0.9872 - val_loss: 0.0327 - val_accuracy: 0.9893
# Epoch 8/12
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0476 - accuracy: 0.9866 - val_loss: 0.0294 - val_accuracy: 0.9906
# Epoch 9/12
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0458 - accuracy: 0.9867 - val_loss: 0.0363 - val_accuracy: 0.9905
# Epoch 10/12
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0481 - accuracy: 0.9868 - val_loss: 0.0288 - val_accuracy: 0.9903
# Epoch 11/12
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0487 - accuracy: 0.9871 - val_loss: 0.0556 - val_accuracy: 0.9894
# Epoch 12/12
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0496 - accuracy: 0.9865 - val_loss: 0.0323 - val_accuracy: 0.9898

# %%
# モデルを評価 --- (*5)
score = model.evaluate(X_test, y_test, verbose=1)
print('正解率=', score[1], 'loss=', score[0])
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0323 - accuracy: 0.9898
# 正解率= 0.989799976348877 loss= 0.03234166279435158

# %%
# 学習の様子をグラフへ描画 --- (*6)
# 正解率の推移をプロット
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# ロスの推移をプロット
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

filename = '数字の2a.jpg'
img = cv2.imread(filename)
plt.imshow(img)
plt.axis("off")
plt.show()
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img = cv2.resize(img,(28,28))
img = 255 - img
# CNNモデルに対応するようにデータを(1, 28, 28)の三次元配列に変換
img = img.reshape(1, 28, 28, 1).astype('float32') / 255
ans = model.predict(img)
print("この画像の数字は" +  str(np.argmax(ans)) + "です \n")
# Out:
# この画像の数字は2です
