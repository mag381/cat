# %% [markdown]
# <a href="https://colab.research.google.com/github/mag381/cat/blob/main/%E3%83%A9%E3%82%A4%E3%82%AA%E3%83%B3%E3%81%A8%E7%8C%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 画像に映っているものを当てるための準備
import h5py
from tensorflow.keras.preprocessing import image
from keras.applications.inception_v3 import preprocess_input, decode_predictions, InceptionV3
import numpy as np

# %%
# 画像の読み込みと, 画像の表示のための準備
from PIL import Image
from IPython.display import display

# %%
# 画像ファイルの読み込みと，画像の表示
filename = "ライオン.jpg"
img = Image.open(filename)
display(img)

# %%
m = InceptionV3(weights='imagenet')

img_path = filename
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = m.predict(x)

print('Predicted:')
for p in decode_predictions(preds, top=3)[0]:
    print("{},  {}".format(p[1], p[2]))
