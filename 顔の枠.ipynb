# %% [markdown]
# <a href="https://colab.research.google.com/github/mag381/cat/blob/main/%E9%A1%94%E3%81%AE%E6%9E%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt
# !wget -q  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_alt.xml
cascade = cv2.CascadeClassifier('./haarcascade_frontalface_alt.xml')

# %%
img = cv2.imread('face-mona.jpg')
image_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
waku = cascade.detectMultiScale(image_gray)
if len(waku) > 0:
   for x, y, w, h in waku:
        cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)

# %%
image2 = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.axis('off')
plt.imshow(image2)
